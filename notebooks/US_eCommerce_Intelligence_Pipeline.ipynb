# %%
# !pip install kagglehub

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("ammaraahmad/us-ecommerce-record-2020")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'us-ecommerce-record-2020' dataset.
# Path to dataset files: /kaggle/input/us-ecommerce-record-2020

# %%
import os

print(os.listdir(path))
# Out:
# ['US  E-commerce records 2020.csv']

# %%
import pandas as pd
import os

# %%
file_path = os.path.join(path, "US  E-commerce records 2020.csv")

df = pd.read_csv(file_path, encoding='latin-1')

# %%
df. head(3
         )
# Out:
#   Order Date  Row ID        Order ID       Ship Mode Customer ID      Segment  \
# 0   01-01-20     849  CA-2017-107503  Standard Class    GA-14725     Consumer
# 1   01-01-20    4010  CA-2017-144463  Standard Class    SC-20725     Consumer
# 2   01-01-20    6683  CA-2017-154466     First Class    DP-13390  Home Office
#
#          Country         City       State  Postal Code   Region  \
# 0  United States       Lorain        Ohio        44052     East
# 1  United States  Los Angeles  California        90036     West
# 2  United States     Franklin   Wisconsin        53132  Central
#
#         Product ID         Category Sub-Category  \
# 0  FUR-FU-10003878        Furniture  Furnishings
# 1  FUR-FU-10001215        Furniture  Furnishings
# 2  OFF-BI-10002012  Office Supplies      Binders
#
#                                         Product Name    Sales  Quantity  \
# 0                 Linden 10" Round Wall Clock, Black   48.896         4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3312 entries, 0 to 3311
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order Date    3312 non-null   object
#  1   Row ID        3312 non-null   int64
#  2   Order ID      3312 non-null   object
#  3   Ship Mode     3312 non-null   object
#  4   Customer ID   3312 non-null   object
#  5   Segment       3312 non-null   object
#  6   Country       3312 non-null   object
#  7   City          3312 non-null   object
#  8   State         3312 non-null   object
#  9   Postal Code   3312 non-null   int64
#  10  Region        3312 non-null   object
#  11  Product ID    3312 non-null   object
#  12  Category      3312 non-null   object
#  13  Sub-Category  3312 non-null   object
#  14  Product Name  3312 non-null   object
#  15  Sales         3312 non-null   float64
#  16  Quantity      3312 non-null   int64
#  17  Discount      3312 non-null   float64
# ...

# %%
df.shape
# Out:
# (3312, 19)

# %%
df.columns
# Out:
# Index(['Order Date', 'Row ID', 'Order ID', 'Ship Mode', 'Customer ID',
#        'Segment', 'Country', 'City', 'State', 'Postal Code', 'Region',
#        'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Sales',
#        'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ','_')

# %%
df.head(1)
# Out:
#   order_date  row_id        order_id       ship_mode customer_id   segment  \
# 0   01-01-20     849  CA-2017-107503  Standard Class    GA-14725  Consumer
#
#          country    city state  postal_code region       product_id  \
# 0  United States  Lorain  Ohio        44052   East  FUR-FU-10003878
#
#     category sub-category                        product_name   sales  \
# 0  Furniture  Furnishings  Linden 10" Round Wall Clock, Black  48.896
#
#    quantity  discount  profit
# 0         4       0.2  8.5568

# %%
#df.isnull().sum()

(df.isnull().sum() / len(df)) * 100
# Out:
# order_date      0.0
# row_id          0.0
# order_id        0.0
# ship_mode       0.0
# customer_id     0.0
# segment         0.0
# country         0.0
# city            0.0
# state           0.0
# postal_code     0.0
# region          0.0
# product_id      0.0
# category        0.0
# sub-category    0.0
# product_name    0.0
# sales           0.0
# quantity        0.0
# discount        0.0
# profit          0.0
# dtype: float64

# %%
df['order_date'] = pd.to_datetime(df['order_date'])
# Out:
# /tmp/ipykernel_497/2765250300.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['order_date'] = pd.to_datetime(df['order_date'])

# %%
df['ship_mode'] = df['ship_mode'].astype('category')

# %%
df['segment'] = df['segment'].astype('category')

# %%
df['region'] = df['region'].astype('category')
df['category'] = df['category'].astype('category')

# %%
df.columns = df.columns.str.replace('-', '_')

# %%
df['sub_category'] = df['sub_category'].astype('category')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['profit_margin'] = df['profit'] / df['sales']

# %%
df['is_loss'] = df['profit'] < 0

# %%
df['order_month'] = df['order_date'].dt.month

# %%
df['sales_per_unit'] = df['sales'] / df['quantity']

# %%
df.head(3)
# Out:
#   order_date  row_id        order_id       ship_mode customer_id      segment  \
# 0 2020-01-01     849  CA-2017-107503  Standard Class    GA-14725     Consumer
# 1 2020-01-01    4010  CA-2017-144463  Standard Class    SC-20725     Consumer
# 2 2020-01-01    6683  CA-2017-154466     First Class    DP-13390  Home Office
#
#          country         city       state  postal_code  ... sub_category  \
# 0  United States       Lorain        Ohio        44052  ...  Furnishings
# 1  United States  Los Angeles  California        90036  ...  Furnishings
# 2  United States     Franklin   Wisconsin        53132  ...      Binders
#
#                                         product_name    sales quantity  \
# 0                 Linden 10" Round Wall Clock, Black   48.896        4
# 1  Howard Miller 11-1/2" Diameter Brentwood Wall ...  474.430       11
# 2            Wilson Jones Easy Flow II Sheet Lifters    3.600        2
#
# ...

# %%
import os

os.makedirs("data/cleaned", exist_ok=True)

# %%
df.to_csv("data/cleaned/ecommerce_cleaned.csv", index=False)

# %%
df.head(3)
# Out:
#   order_date  row_id        order_id       ship_mode customer_id      segment  \
# 0 2020-01-01     849  CA-2017-107503  Standard Class    GA-14725     Consumer
# 1 2020-01-01    4010  CA-2017-144463  Standard Class    SC-20725     Consumer
# 2 2020-01-01    6683  CA-2017-154466     First Class    DP-13390  Home Office
#
#          country         city       state  postal_code  ... sub_category  \
# 0  United States       Lorain        Ohio        44052  ...  Furnishings
# 1  United States  Los Angeles  California        90036  ...  Furnishings
# 2  United States     Franklin   Wisconsin        53132  ...      Binders
#
#                                         product_name    sales quantity  \
# 0                 Linden 10" Round Wall Clock, Black   48.896        4
# 1  Howard Miller 11-1/2" Diameter Brentwood Wall ...  474.430       11
# 2            Wilson Jones Easy Flow II Sheet Lifters    3.600        2
#
# ...

# %%
from google.colab import files
files.download("data/cleaned/ecommerce_cleaned.csv")
